# %% [markdown]
# <a href="https://colab.research.google.com/github/IDTBDM1716/Code-for-Africa/blob/main/Idossa_Dhibissa_First_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Idossa Dhibissa | Portfolio</title>
  <style>
    body {
      font-family: Arial, sans-serif;
      background-color: #e5e5e5;
      margin: 0;
      padding: 0;
      overflow: hidden; /* Prevent scrolling during animation */
    }

    /* Loader Animation */
    .main_spinner {
      position: fixed;
      top: 50%;
      left: 50%;
      transform: translate(-50%, -50%);
      display: flex;
      justify-content: center;
      align-items: center;
      z-index: 999;
    }
    .center_mass {
      width: 30px;
      height: 30px;
      background-color: #3498db;
      border-radius: 50%;
    }
    .dot {
      width: 10px;
      height: 10px;
      background-color: #e74c3c;
      border-radius: 50%;
      margin: 0 5px;
      animation: bounce 1.5s infinite;
    }
    .dot_1 {
      animation-delay: 0.3s;
    }
    .dot_2 {
      animation-delay: 0.6s;
    }
    @keyframes bounce {
      0%, 100% {
        transform: scale(1);
      }
      50% {
        transform: scale(1.5);
      }
    }

    /* Navigation bar */
    nav {
      background-color: #333;
      color: white;
      padding: 20px;
      display: flex;
      justify-content: space-between;
      align-items: center;
    }
    .nav-links {
      list-style: none;
      display: flex;
    }
    .nav-links li {
      margin-left: 15px;
    }
    .nav-links a {
      color: white;
      text-decoration: none;
      font-weight: bold;
    }

    /* Hero Section */
    .hero {
      background-color: #34495e;
      color: white;
      padding: 80px 20px;
      text-align: center;
    }
    .hero .highlight {
      color: #ff7f50;
    }

    .btn {
      background-color: #ff7f50;
      padding: 10px 20px;
      color: white;
      text-decoration: none;
      border-radius: 5px;
      font-weight: bold;
    }

    /* About Section */
    .about, .projects, .contact {
      padding: 50px 20px;
      text-align: center;
    }

    /* Project Cards */
    .project-card {
      background-color: #fff;
      margin: 20px;
      padding: 20px;
      border-radius: 5px;
      box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
    }
    .project-card a {
      text-decoration: none;
      color: #3498db;
    }

    /* Footer */
    footer {
      background-color: #2c3e50;
      color: white;
      padding: 20px;
      text-align: center;
    }

    /* Canvas for Animation */
    #animationCanvas {
      position: fixed;
      top: 0;
      left: 0;
      width: 100%;
      height: 100%;
      z-index: -1;
    }
  </style>
</head>
<body>

  <!-- Loader Animation -->
  <div class="main_spinner">
    <div class="center_mass"></div>
    <div class="dot dot_1"></div>
    <div class="dot dot_2"></div>
  </div>

  <!-- Navigation -->
  <nav>
    <div class="logo">Idossa Dhibissa</div>
    <ul class="nav-links">
      <li><a href="#about">About</a></li>
      <li><a href="#projects">Projects</a></li>
      <li><a href="#contact">Contact</a></li>
    </ul>
  </nav>

  <!-- Hero Section -->
  <header class="hero">
    <h1>Hello, I'm <span class="highlight">Idossa Dhibissa</span></h1>
    <p>4th-year Information Science student | Full-Stack Developer | Cloud Computing Enthusiast</p>
    <a href="#projects" class="btn">View My Work</a>
  </header>

  <!-- About Section -->
  <section id="about">
    <h2>About Me</h2>
    <p>
      I'm a passionate full-stack developer skilled in cloud computing, AI, and system administration.
      I have experience in developing scalable applications and freelancing platforms like Arfiget.
      I also have leadership experience as a youth commissioner and scout leader. I'm dedicated to leveraging technology to solve real-world problems, especially in underserved communities.
    </p>
    <p>
      Throughout my academic journey, I have worked on various projects that demonstrate my expertise in both the frontend and backend development, cloud solutions, and user-focused design.
    </p>
    <img src="https://gravatar.com/delightfulrebel38a686ac4c" alt="Idossa Dhibissa" width="200" height="200">
  </section>

  <!-- Projects Section -->
  <section id="projects">
    <h2>Projects</h2>
    <div class="project-card">
      <h3>Arfiget</h3>
      <p>A freelancing platform for Ethiopia & Africa, built with ASP.NET Core and Next.js. It allows users to create profiles, post jobs, and connect with freelancers in a seamless and intuitive environment.</p>
      <a href="https://github.com/IdossaDhibissa/arfiget" target="_blank">View Demo</a>
    </div>

    <div class="project-card">
      <h3>OrthoNet</h3>
      <p>A web platform for religious education with features such as FAQs, online classes, post-reminders, and interactive question spaces. It's designed to foster better understanding of Orthodox Christianity and other religions.</p>
      <a href="https://github.com/IdossaDhibissa/OrthoNet" target="_blank">View Demo</a>
    </div>

    <div class="project-card">
      <h3>Prolancer</h3>
      <p>A freelancing service platform with built-in features for job posting, profile management, and secure payment systems. Developed using Django and designed to empower freelancers in emerging markets.</p>
      <a href="https://github.com/IdossaDhibissa/Prolancer" target="_blank">View Demo</a>
    </div>

    <div class="project-card">
      <h3>Smart E-Commerce</h3>
      <p>A comprehensive e-commerce platform with digital product sales, course sales, and a freelancing feature. It mimics popular platforms like Envato and Udemy, focusing on providing a seamless experience for digital product creators and consumers.</p>
      <a href="https://github.com/IdossaDhibissa/Smart-E-Commerce" target="_blank">View Demo</a>
    </div>

    <div class="project-card">
      <h3>SecureLogin</h3>
      <p>A secure login system built using Next.js and SQL Server, designed to handle user authentication with encryption and session management, ensuring a high level of security and scalability.</p>
      <a href="https://github.com/IdossaDhibissa/SecureLogin" target="_blank">View Demo</a>
    </div>
  </section>

  <!-- Contact Section -->
  <section id="contact">
    <h2>Contact Me</h2>
    <p>Email: <a href="mailto:idodawit@gmail.com">idodawit@gmail.com</a></p>
    <p>LinkedIn: <a href="https://www.linkedin.com/in/idossa-dhibissa-a7b488299" target="_blank">LinkedIn Profile</a></p>
    <p>GitHub: <a href="https://github.com/IDTBDM1716" target="_blank">GitHub Profile</a></p>
    <p>Phone: +251917165193</p>
  </section>

  <footer>
    <p>&copy; 2025 Idossa Dhibissa | All Rights Reserved</p>
  </footer>

  <!-- Canvas for Animation -->
  <canvas id="animationCanvas"></canvas>

  <script>
    const canvas = document.getElementById('animationCanvas');
    const ctx = canvas.getContext('2d');
    canvas.width = window.innerWidth;
    canvas.height = window.innerHeight;

    const Vector = {
      fa: (angle, magnitude) => {
        return {
          _.add: (vec) => vec
        }
      }
    };
    let rotate = function(deg) { return deg; }
    function draw(time) {
      const sideCount = 14;
      const count = sideCount * sideCount;
      const size = 500;
      const subSize = size / sideCount;
      for (let i = 0; i < count; i++) {
        const pos = {
          mag: () => Math.random(),
          sub: (value) => {}
        };
        const dt = pos.mag() / 2;
        const count2 = 6 + dt * 10 + Math.sin(time * 4.5 - dt * Math.PI * 2.5) * 2;
        ctx.beginPath();
        for (let j = 0; j < count2; j++) {
          ctx.arc(250, 250, 100, 0, Math.PI * 2);
          ctx.stroke();
        }
      }
    }
    window.requestAnimationFrame(draw);
  </script>

</body>
</html>
"""

# Display the HTML content with the animation
display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Idossa Dhibissa | Portfolio</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #e5e5e5;
#       margin: 0;
#       padding: 0;
#       overflow: hidden; /* Prevent scrolling during animation */
#     }
#
#     /* Loader Animation */
#     .main_spinner {
#       position: fixed;
#       top: 50%;
#       left: 50%;
#       transform: translate(-50%, -50%);
#       display: flex;
#       justify-content: center;
#       align-items: center;
#       z-index: 999;
#     }
#     .center_mass {
#       width: 30px;
#       height: 30px;
#       background-color: #3498db;
#       border-radius: 50%;
#     }
#     .dot {
#       width: 10px;
#       height: 10px;
#       background-color: #e74c3c;
#       border-radius: 50%;
#       margin: 0 5px;
#       animation: bounce 1.5s infinite;
# ...

# %%
# !pip install pyngrok

# %%
# !git config --global user.name "Idossa Dhibissa"
# !git config --global user.email "idodawit@gmail.com"

# %%
# !git config --global --list
# Out:
# user.name=Idossa Dhibissa
# user.email=idodawit@gmail.com

# %%
# !git clone https://github.com/IDTBDM1716/my-colab-project.git
# Out:
# Cloning into 'my-colab-project'...
# ...
